# %%
import pandas as pd
import os

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks//woodsfinal/')

# %%
# add second sheet of data, DF2
gradrates = pd.read_csv('urban_data_science_gradrates.csv')

# %%
gradrates
# Out:
#    Year Graduation Rate (All) Black Graduation Rate White Graduation Rate
# 0  2018                86.69%                83.68%                88.92%
# 1  2019                88.27%                86.37%                90.07%
# 2  2020                87.70%                86.24%                89.16%
# 3  2021                87.02%                84.75%                89.75%
# 4  2022                87.79%                85.20%                91.54%

# %%
df = gradrates

# %%
# Remove percent sign from all columns
new_df = df.applymap(lambda x: x.replace('%', '') if isinstance(x, str) else x)

new_df
# Out:
#    Year Graduation Rate (All) Black Graduation Rate White Graduation Rate
# 0  2018                 86.69                 83.68                 88.92
# 1  2019                 88.27                 86.37                 90.07
# 2  2020                 87.70                 86.24                 89.16
# 3  2021                 87.02                 84.75                 89.75
# 4  2022                 87.79                 85.20                 91.54

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_df.columns
# Out:
# Index(['Year', 'Graduation Rate (All)', 'Black Graduation Rate',
#        'White Graduation Rate'],
#       dtype='object')

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Set year as the index
dex_df = new_df.set_index('Year')

# %%
'''# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.25
index = np.arange(len(df.index))
for i, column in enumerate(['White Graduation Rate', 'Black Graduation Rate', 'Graduation Rate (All)']):
    plt.bar(index + i * bar_width, df[column], width=bar_width, label=column)

plt.xlabel('Year')
plt.ylabel('Graduation Rate (%)')
plt.title('Graduation Rates by Year and Race')
plt.xticks(index + bar_width, df.index)
plt.legend(title='Race')
plt.ylim(0, df.max().max() + 5)  # Set the y-axis limits
plt.tight_layout()
plt.show()'''
# Out:
# "# Plotting\nplt.figure(figsize=(10, 6))\nbar_width = 0.25\nindex = np.arange(len(df.index))\nfor i, column in enumerate(['White Graduation Rate', 'Black Graduation Rate', 'Graduation Rate (All)']):\n    plt.bar(index + i * bar_width, df[column], width=bar_width, label=column)\n\nplt.xlabel('Year')\nplt.ylabel('Graduation Rate (%)')\nplt.title('Graduation Rates by Year and Race')\nplt.xticks(index + bar_width, df.index)\nplt.legend(title='Race')\nplt.ylim(0, df.max().max() + 5)  # Set the y-axis limits\nplt.tight_layout()\nplt.show()"

# %%
# Plotting
'''
plt.figure(figsize=(12, 6))
bar_width = 0.3
index = np.arange(len(new_df))
for i, column in enumerate(['White Graduation Rate', 'Black Graduation Rate', 'Graduation Rate (All)']):
    plt.bar(index + i * bar_width, new_df[column], width=bar_width, label=column)

plt.xlabel('Year')
plt.ylabel('Graduation Rate (%)')
plt.title('Graduation Rates by Year and Race')

# Use years as x-axis labels instead of index numbers
plt.xticks(index + bar_width * 1.5, new_df.index)

plt.legend(title='Race')


plt.tight_layout()
plt.show() '''
# Out:
# "\nplt.figure(figsize=(12, 6))\nbar_width = 0.3\nindex = np.arange(len(new_df))\nfor i, column in enumerate(['White Graduation Rate', 'Black Graduation Rate', 'Graduation Rate (All)']):\n    plt.bar(index + i * bar_width, new_df[column], width=bar_width, label=column)\n\nplt.xlabel('Year')\nplt.ylabel('Graduation Rate (%)')\nplt.title('Graduation Rates by Year and Race')\n\n# Use years as x-axis labels instead of index numbers\nplt.xticks(index + bar_width * 1.5, new_df.index)\n\nplt.legend(title='Race')\n\n\nplt.tight_layout()\nplt.show() "

# %%
new_df_sorted
# Out:
#    Year Graduation Rate (All) Black Graduation Rate White Graduation Rate
# 0  2018                 86.69                 83.68                 88.92
# 1  2019                 88.27                 86.37                 90.07
# 2  2020                 87.70                 86.24                 89.16
# 3  2021                 87.02                 84.75                 89.75
# 4  2022                 87.79                 85.20                 91.54

# %%
plt.figure(figsize=(12, 6))
bar_width = 0.3

df = new_df.set_index('Year')
df = df.astype(float)

df.plot(kind='bar')
plt.ylim(60, 100)
plt.ylabel('Graduation Rate (%)')
plt.title('Graduation Rates by Year')
plt.legend(title='Race')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
#plt.figure(figsize=(12, 6))
#bar_width = 0.3
#index = np.arange(len(dex_df))
#new_df_year_index = new_df.set_index('Year')

#new_df_float = new_df_year_index.astype(float)
#sorted_df = new_df_float.sort_index()
#normalized_df = (sorted_df - sorted_df.min()) / (sorted_df.max() - sorted_df.min()) * 100

#for i, column in enumerate(['White Graduation Rate', 'Black Graduation Rate', 'Graduation Rate (All)']):
#    plt.bar(index + i * bar_width, normalized_df[column], width=bar_width, label=column)

#plt.xlabel('Year')
#plt.ylabel('Graduation Rate (%)')
#plt.title('Graduation Rates by Year and Race')

# Use index (year) as x-axis labels
#plt.xticks(index + bar_width * 1.5, dex_df.index)

#plt.legend(title='Race')

#plt.tight_layout()
#plt.show()
