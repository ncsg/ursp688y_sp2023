# %%
import taiwo_exercise05

# %%
file_path = '/content/drive/MyDrive/Tayo Exercise/affordable_housing.csv'
housing_project = taiwo_exercise05.load_and_prepare_housing_data(file_path)
if housing_project is not None:
    taiwo_exercise05.plot_project_status_by_ward(housing_project)
    taiwo_exercise05.plot_affordable_units_by_ward(housing_project, 'Under Construction', '0_30')
