# %%
# import pandas and os
# mount drive
import pandas as pd
import os

from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/Excercise04_Fahmi')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import housingstatus

# %%
from housingstatus import housing_status
#could not do it in last excercise, figured out why

# %%
housing_status()
# could not use this for plotting
# Out:
# /content/drive/MyDrive/Colab Notebooks/Excercise04_Fahmi/housingstatus.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_projects_filtered['Total_Units'] = housing_projects_filtered['AFFORDABLE_UNITS_AT_0_30_AMI']+ housing_projects_filtered['AFFORDABLE_UNITS_AT_31_50_AMI']++housing_projects_filtered['AFFORDABLE_UNITS_AT_51_60_AMI']
#     MAR_WARD       STATUS_PUBLIC  AFFORDABLE_UNITS_AT_0_30_AMI  \
# 0     Ward 6  Under Construction                             2
# 13    Ward 8            Pipeline                             0
# 56    Ward 6            Pipeline                           140
# 58    Ward 1  Under Construction                             0
# 59    Ward 1            Pipeline                            90
# ..       ...                 ...                           ...
# 850   Ward 5            Pipeline                             0
# 857   Ward 3            Pipeline                             0
# 863   Ward 4  Under Construction                             0
# 869   Ward 5  Under Construction                             0
# 871   Ward 4  Under Construction                             0
#
#      AFFORDABLE_UNITS_AT_31_50_AMI  AFFORDABLE_UNITS_AT_51_60_AMI  Total_Units
# 0                                4                             12           18
# 13                               0                            134          134
# 56                               0                            139          279
# 58                              12                              0           12
# 59                               0                            111          201
# ..                             ...                            ...          ...
# 850                              0                              4            4
# 857                              0                             30           30
# 863                              1                              1            2
# 869                              1                              2            3
# 871                              0                              3            3
#
# [352 rows x 6 columns]

# %%
import seaborn as sb

# %%
# reusable code with changable status_filter
affordable_housing = pd.read_csv('affordable_housing.csv')
idx = affordable_housing[affordable_housing['MAR_WARD'] == '1'].index[0]
affordable_housing.at[idx, 'MAR_WARD'] = 'Ward 1'

small_data_set = affordable_housing[['MAR_WARD','STATUS_PUBLIC','TOTAL_AFFORDABLE_UNITS']]
status_filter = small_data_set[small_data_set['STATUS_PUBLIC'].isin(['Under Construction'])]

data_plot = pd.DataFrame(status_filter.groupby('MAR_WARD')['TOTAL_AFFORDABLE_UNITS'].sum())
sb.barplot(data = data_plot , x = 'MAR_WARD' , y = 'TOTAL_AFFORDABLE_UNITS')
# Out:
# <Axes: xlabel='MAR_WARD', ylabel='TOTAL_AFFORDABLE_UNITS'>

# %%
affordable_housing = pd.read_csv('affordable_housing.csv')
idx = affordable_housing[affordable_housing['MAR_WARD'] == '1'].index[0]
affordable_housing.at[idx, 'MAR_WARD'] = 'Ward 1'

small_data_set = affordable_housing[['MAR_WARD','STATUS_PUBLIC','TOTAL_AFFORDABLE_UNITS']]
status_filter = small_data_set[small_data_set['STATUS_PUBLIC'].isin(['Pipeline'])]

data_plot = pd.DataFrame(status_filter.groupby('MAR_WARD')['TOTAL_AFFORDABLE_UNITS'].sum())
sb.barplot(data = data_plot , x = 'MAR_WARD' , y = 'TOTAL_AFFORDABLE_UNITS')
# Out:
# <Axes: xlabel='MAR_WARD', ylabel='TOTAL_AFFORDABLE_UNITS'>
