# %%
#Exercice_part_1
#Publish bad vizualization example
from IPython.display import Image, display
import requests
from io import BytesIO

# Image URL
image_url = 'https://i0.wp.com/www.codeconquest.com/wp-content/uploads/image-16.png?w=2048&ssl=1'

# Fetch the image
response = requests.get(image_url)

# Display the image
display(Image(data=response.content))

# %%
#Exercice_part_2

import pandas as pd

# %%
#Import drive to Collab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#set the current working directory path
import os
os.getcwd()

os.chdir('/content/drive/Shareddrives/URSP 688Y')

# %%
import housing

# %%
from housing import calc_affordable_housing_per_ward

calc_affordable_housing_per_ward()
