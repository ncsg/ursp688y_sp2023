# %%
import geopandas as gpd
import requests
from shapely.geometry import Point
import pandas as pd

def get_travel_time(origin, destination, api_key):
    origin_str = f"{origin.y},{origin.x}"
    destination_str = f"{destination.y},{destination.x}"
    url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin_str}&destination={destination_str}&mode=transit&key={api_key}"
    response = requests.get(url)
    data = response.json()
    if data['status'] == 'OK':
        routes = data['routes']
        if routes:
            legs = routes[0]['legs']
            if legs:
                return legs[0]['duration']['value']
    return None

def main():
    # Google API Key
    api_key = "AIzaSyCfRO-wrPncy3E-SHxzorKDmJxkiKtJX_c"
    
    # Read block centroid shapefile
    blocks = gpd.read_file('Centroid_DC_tract.shp')

    # Read hospitals shapefile
    hospitals = gpd.read_file('Hospitals_DC.shp')
    
    # Initialize list to store results
    results = []
    
    # Iterate over blocks and hospitals
    for index, block in blocks.iterrows():
        block_centroid = block.geometry.centroid
        for index, hospital in hospitals.iterrows():
            hospital_location = hospital.geometry
            travel_time = get_travel_time(block_centroid, hospital_location, api_key)
            if travel_time and travel_time <= 45 * 60:  # Convert 45 minutes to seconds
                results.append({
                    'Block_ID': block['GEOID'],
                    'Hospital_Name': hospital['NAME'],
                    'Travel_Time_Seconds': travel_time
                })
            else:
                print(f"Failed to retrieve or exceed travel time threshold from block centroid {block['GEOID']} to hospital {hospital['NAME']}.")

    # Convert results to DataFrame
    df = pd.DataFrame(results)
    
    # Save DataFrame to CSV file
    df.to_csv('travel_times_within_threshold.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005302 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004402 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004402 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004402 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004402 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004402 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010602 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000804 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003902 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000903 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001004 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000102 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003701 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002504 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000101 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000703 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003901 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004401 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001003 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003802 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002703 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003702 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000803 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003801 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000904 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001000704 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001304 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001303 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002704 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002503 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005601 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005501 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005602 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005502 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005303 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010202 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001980000 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007202 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005202 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005203 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005003 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005003 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005003 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005003 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005004 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005004 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005004 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005004 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001007201 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005802 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005802 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004703 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001004704 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010603 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010603 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010603 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010603 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010601 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010601 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010601 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010601 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010601 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001011002 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001010201 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# ...
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001901 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001001902 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005001 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005001 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005001 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005001 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001005001 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009807 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009802 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital CHILDREN'S NATIONAL MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital HOWARD UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital MEDSTAR NATIONAL REHABILITATION HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital MEDSTAR WASHINGTON HOSPITAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001009803 to hospital WASHINGTON VA MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002002 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital PROVIDENCE HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital PSYCHIATRIC INSTITUTE OF WASHINGTON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002101 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital BRIDGEPOINT HOSPITAL CAPITOL HILL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001002900 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003100 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital GEORGE WASHINGTON UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003200 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003400 to hospital UNITED MEDICAL CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital 316TH MEDICAL SQUADRON.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital HOSPITAL FOR SICK CHILDREN AND PEDIATRIC CENTER.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital MEDSTAR - GEORGETOWN UNIVERSITY HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital SIBLEY MEMORIAL HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital BRIDGEPOINT HOSPITAL NATIONAL HARBOR.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital SAINT ELIZABETH'S HOSPITAL.
# Failed to retrieve or exceed travel time threshold from block centroid 11001003500 to hospital UNITED MEDICAL CENTER.
